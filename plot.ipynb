# %%
from pytsc.backends.sumo import SUMO_MODULES

# %%
SCENARIO = "cologne8"

# %%
config = SUMO_MODULES["config"](SCENARIO)
network_parser = SUMO_MODULES["network_parser"](config)
# Out:
# 2025-02-10 10:18:08,855 - INFO - Scenario config file: /home/rohitbokade/repos/pytsc/pytsc/common/../scenarios/sumo/cologne8/config.yaml
# 2025-02-10 10:18:08,856 - INFO - Config:
# {   'cityflow': {   'delta_time': 5,
#                     'episode_limit': 360,
#                     'flow_rate_type': 'constant',
#                     'initial_wait_time': 0,
#                     'interval': 1.0,
#                     'lane_change': False,
#                     'rl_traffic_light': True,
#                     'save_replay': False,
#                     'seed': 42,
#                     'sim_length': 3600,
#                     'thread_num': 1,
#                     'veh_size_min_gap': 7.5,
#                     'vehicle_length': 5},
#     'misc': {   'flickering_coef': 0.01,
#                 'max_hops': 1,
#                 'max_wait_time': 1000,
#                 'pad_value': 0.0,
#                 'return_agent_stats': False,
#                 'return_lane_stats': False,
# ...

# %%
network_parser.plot_network(figsize=(6, 6))
